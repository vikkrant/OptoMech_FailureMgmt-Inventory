# %%
import pandas 
from sklearn import preprocessing as pp
df = pandas.read_excel("724Ready.xlsx")
#Creating Hashmap using data gathered up until 8/22
compRecords = {}
for index in range(0,df.shape[0]):
    dfElement = df.iloc[index]
    serNum = dfElement["Serial Number W/O Production Number"]
    
    if dfElement["Classification"] == "Failure":
        failedComponent = 1
    else:
        failedComponent = 0

    if serNum in compRecords:
        compRecords[serNum] = (compRecords[serNum][0] + failedComponent, compRecords[serNum][1] + 1)
    else:
        compRecords[serNum] = (failedComponent, 1)
    
#Hashmap Created -- Now Write to the DataFrame
for index in range(0,df.shape[0]):
    compSerNum = df.iloc[index]["Serial Number W/O Production Number"]
    df.loc[index,"Amount Failed"] = compRecords[compSerNum][0]
    df.loc[index,"Total Amount"] = compRecords[compSerNum][1]
    df.loc[index,"Rate of Failure"] = round(compRecords[compSerNum][0]/compRecords[compSerNum][1],2)
print(df)
# Out:
#    Deployment Date Failure Date  Time to Failure    Hutch  \
# 0       2023-05-01   2023-02-05              NaN    LM1K4
# 1              NaT   2023-11-22              NaN  Unknown
# 2              NaT   2023-11-22              NaN  Unknown
# 3              NaT   2023-11-22              NaN  Unknown
# 4              NaT   2023-11-22              NaN  Unknown
# 5              NaT   2023-11-22              NaN  Unknown
# 6       2023-05-01   2023-11-27            210.0    LM1K4
# 7       2023-05-01   2023-11-27            210.0    LM1K4
# 8       2023-05-01   2023-11-27            210.0    LM1K4
# 9       2023-05-01   2024-01-01            245.0    LM1K4
# 10      2023-05-01   2024-01-30            274.0    LM1K4
# 11      2023-05-01   2024-01-30            274.0    LM1K4
# 12      2023-08-01   2024-02-05            188.0    LM2K2
# 13      2023-08-01   2024-02-05            188.0    LM2K2
# 14      2023-08-01   2024-02-14            197.0    LM2K2
# 15      2023-08-01   2024-02-27            210.0    LM2K2
# 16      2023-08-01   2024-02-29            212.0    LM2K2
# 17      2023-08-01   2024-02-29            212.0    LM2K2
# 18      2023-08-01   2024-04-22            265.0    LM2K2
# 19      2023-05-01   2024-05-26            391.0    LM1K4
# 20      2023-08-01   2024-06-12            316.0    LM2K2
# 21      2023-05-01   2024-06-28            424.0    LM1K4
# 22      2023-05-01   2024-07-04            430.0    LM1K4
#
#    Serial Number W/O Production Number  Production Number           PV Base  \
# 0                             SLLV42sc              463.0           Unknown
# 1                             STT50.8v                6.0           Unknown
# 2                              SR7012l               18.0           Unknown
# 3                             STT25.4v               25.0           Unknown
# 4                             STT50.8v               29.0           Unknown
# 5                            SLC1780ds               40.0           Unknown
# 6                             STT25.4v               21.0       HRM_MP1_MR4
# 7                             STT25.4v                NaN       ATM_MP1_MR0
# 8                             STT25.4v                NaN       ATM_MP1_MR1
# 9                             STT25.4v               27.0       ATM_MP1_MR0
# 10                           SLC1780ds                NaN           Unknown
# 11                             CLL42lc                NaN           Unknown
# 12                             CLL42lc               47.0           Unknown
# 13                            STT25.4v                NaN           Unknown
# 14                            STT25.4v               24.0       EJX_MP1_MR1
# 15                           STT50.8iv                NaN           Unknown
# 16                           STT50.8iv                6.0  ATM_MP1_IMG1_BS1
# 17                            STT50.8v                6.0  ATM_MP1_IMG1_BS3
# 18                           SLC2445ds                NaN           Unknown
# 19                           SLC1740ds               85.0           Unknown
# 20                            SLLV42lc              473.0   EJX_MP1_LS1_LM1
# 21                            SLLV42lc              469.0           Unknown
# 22                           SLC1760ds               89.0           Unknown
#
#                                              Symptoms  \
# 0          Unresponsive linear stage AND Piezo damage
# 1                                       Cable Damaged
# 2                                       Piezo burned
# 3                                       Piezo burned
# 4                                       Piezo burned
# 5                                             Unknown
# 6             Unresponsive tilt axis AND Piezo damage
# 7         ATM_MR0_TILT1 unresponsive AND Piezo damage
# 8         ATM_MR1_TILT1 unresponsive AND Piezo damage
# 9                                             Unknown
# 10             Absolute positions change unexpectedly
# 11             Absolute positions change unexpectedly
# 12  Stage failing sporadically in closed-loop move...
# 13                                  Unresponsive axes
# 14                                            Unknown
# 15   Intermittent sensor failure on encoded tilt axis
# 16                                                NaN
# 17                                                NaN
# 18  Stage failing sporadically in closed-loop move...
# 19  Unresponsive stage, Hanging after sticky movem...
# 20             Unresponsive movement AND Piezo Damage
# 21                              Not "homing" properly
# 22               Unresponsive stage AND Piezo damaged
#
#                                    Standardized Classification  Amount Failed  \
# 0                                  Unresponsive        Failure            1.0
# 1                                  Cable Damage        Failure            3.0
# 2                                  Piezo Damage        Failure            1.0
# 3                                  Piezo Damage        Failure            7.0
# 4                                  Piezo Damage        Failure            3.0
# 5                                       Unknown        Failure            2.0
# 6                                  Unresponsive        Failure            7.0
# 7                     Unresponsive,Piezo Damage        Failure            7.0
# 8                     Unresponsive,Piezo Damage        Failure            7.0
# 9                                       Unknown        Failure            7.0
# 10                            Inaccurate Motion        Failure            2.0
# 11                            Inaccurate Motion        Failure            2.0
# 12                            Inaccurate Motion        Failure            2.0
# 13                                 Unresponsive        Failure            7.0
# 14                                      Unknown        Failure            7.0
# 15                        Intermittent Response        Failure            2.0
# 16                                      Unknown        Failure            2.0
# 17                                      Unknown        Failure            3.0
# 18          Inaccurate Motion,Inaccurate Motion        Failure            1.0
# 19  Unresponsive,Inaccurate Motion,Piezo Damage        Failure            1.0
# 20               Inaccurate Motion,Piezo Damage        Failure            2.0
# 21                            Inaccurate Motion        Failure            2.0
# 22                    Unresponsive,Piezo Damage        Failure            1.0
#
#     Total Amount  Rate of Failure
# 0            1.0              1.0
# 1            3.0              1.0
# 2            1.0              1.0
# 3            7.0              1.0
# 4            3.0              1.0
# 5            2.0              1.0
# 6            7.0              1.0
# 7            7.0              1.0
# 8            7.0              1.0
# 9            7.0              1.0
# 10           2.0              1.0
# 11           2.0              1.0
# 12           2.0              1.0
# 13           7.0              1.0
# 14           7.0              1.0
# 15           2.0              1.0
# 16           2.0              1.0
# 17           3.0              1.0
# 18           1.0              1.0
# 19           1.0              1.0
# 20           2.0              1.0
# 21           2.0              1.0
# 22           1.0              1.0

# %%
#-----#1:Binary Encoding Symptoms (Multi-Labeling)------#
mlb = pp.MultiLabelBinarizer()
Y = list(df["Standardized"])
for (k,v) in enumerate(Y):
    if "," in v:
        Y[k] = v.split(",")
    else:
        Y[k] = [v]

#return mlb.fit_transform(Y)

# %%
#-----#2:Filtering Failed Components to be Analyzed------#
allComp = df["Classification"]

indToAnalyze = []
for (k,v) in enumerate(allComp):
    if v == "Failure":
        indToAnalyze.append(v)

#return indToAnalyze
#Use the result of this script and modify the range of features/targets using pandas.iloc

# %%
#-----#3:Calculating Ratio of Failed V/S Working Components------#
#Construct a hashmap where the component's name is the key 
#The value is a tuple of the form (x,y)
#x represents the number of recorded failed units of that component
#y represents the number of total units of that component ever delivered to SLAC 
#------Execution--------#
#Run through the file, one component at a time
#Add the component to the hashmap
#If it is not present already in the map, add it as a key
#If classification is failure => increment the associated failure value by 1 
#And increment the associated total inventory value by 1
#If the classification is inventory => leave the associated failure value as is 
#And increment the total inventory by 1

for index in range(0,df.shape[0]):
    dfElement = df.iloc[index]
    serNum = dfElement["Serial Number W/O Production Number"]
    
    if dfElement["Classification"] == "Failure":
        failedComponent = 1
    else:
        failedComponent = 0

    if serNum in compRecords:
        compRecords[serNum] = (compRecords[serNum][0] + failedComponent, compRecords[serNum] + 1)
    else:
        compRecords[serNum] = (failedComponent, 1)
